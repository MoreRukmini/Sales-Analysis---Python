# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1 = pd.read_csv("C:\BIA Projects\BIA-main\BIA Project & Practise\Project Data\SalesData.csv",index_col=None)

# %%
df1.info
# Out:
# <bound method DataFrame.info of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df1.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df1.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
sns.heatmap(df1.isna(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df1.shape
# Out:
# (9800, 18)

# %%
df1.loc[df1["Postal Code"].isna(),['Country','City','State','Postal Code']]
# Out:
#             Country        City    State  Postal Code
# 2234  United States  Burlington  Vermont          NaN
# 5274  United States  Burlington  Vermont          NaN
# 8798  United States  Burlington  Vermont          NaN
# 9146  United States  Burlington  Vermont          NaN
# 9147  United States  Burlington  Vermont          NaN
# 9148  United States  Burlington  Vermont          NaN
# 9386  United States  Burlington  Vermont          NaN
# 9387  United States  Burlington  Vermont          NaN
# 9388  United States  Burlington  Vermont          NaN
# 9389  United States  Burlington  Vermont          NaN
# 9741  United States  Burlington  Vermont          NaN

# %%
df1.loc[(df1['City']=='Burlington') & (df1['State']=='Vermont'),['Country','Postal Code']]
# Out:
#             Country  Postal Code
# 2234  United States          NaN
# 5274  United States          NaN
# 8798  United States          NaN
# 9146  United States          NaN
# 9147  United States          NaN
# 9148  United States          NaN
# 9386  United States          NaN
# 9387  United States          NaN
# 9388  United States          NaN
# 9389  United States          NaN
# 9741  United States          NaN

# %%
df=df1.copy()       #become performing any operation on data, first create a copy and then perform

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df['Postal Code'] = df['Postal Code'].fillna(5401)

# %%
df.loc[(df1['City']=='Burlington') & (df1['State']=='Vermont'),['Country','Postal Code']]
# Out:
#             Country  Postal Code
# 2234  United States       5401.0
# 5274  United States       5401.0
# 8798  United States       5401.0
# 9146  United States       5401.0
# 9147  United States       5401.0
# 9148  United States       5401.0
# 9386  United States       5401.0
# 9387  United States       5401.0
# 9388  United States       5401.0
# 9389  United States       5401.0
# 9741  United States       5401.0

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop(['Row ID','Customer Name','Order ID','Product ID'],axis=1,inplace=True)

# %%
df[df.duplicated()]
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID      Segment  \
# 3406  23/04/2015  27/04/2015  Standard Class    LB-16795  Home Office
#
#             Country      City State  Postal Code Region   Category  \
# 3406  United States  Columbus  Ohio      43229.0   East  Furniture
#
#      Sub-Category                                       Product Name    Sales
# 3406       Chairs  Global Leather Highback Executive Chair with P...  281.372

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format ='%d/%m/%Y')   #changing date format & removing decimals 
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format = '%d/%m/%Y')
df['Postal Code'] = df['Postal Code'].astype(int)

# %%
df
# Out:
#      Order Date  Ship Date       Ship Mode Customer ID    Segment  \
# 0    2017-11-08 2017-11-11    Second Class    CG-12520   Consumer
# 1    2017-11-08 2017-11-11    Second Class    CG-12520   Consumer
# 2    2017-06-12 2017-06-16    Second Class    DV-13045  Corporate
# 3    2016-10-11 2016-10-18  Standard Class    SO-20335   Consumer
# 4    2016-10-11 2016-10-18  Standard Class    SO-20335   Consumer
# ...         ...        ...             ...         ...        ...
# 9795 2017-05-21 2017-05-28  Standard Class    SH-19975  Corporate
# 9796 2016-01-12 2016-01-17  Standard Class    CS-12490  Corporate
# 9797 2016-01-12 2016-01-17  Standard Class    CS-12490  Corporate
# 9798 2016-01-12 2016-01-17  Standard Class    CS-12490  Corporate
# 9799 2016-01-12 2016-01-17  Standard Class    CS-12490  Corporate
#
#             Country             City       State  Postal Code   Region  \
# 0     United States        Henderson    Kentucky        42420    South
# ...

# %%
df.insert(loc=4, column='order_month_year', value=df['Order Date'].dt.to_period('M'))  
df.insert(loc=5, column='ship_month_year', value=df['Ship Date'].dt.to_period('M'))

# %%
df.insert(loc=6, column='Order_day', value=df['Order Date'].dt.day)
df.insert(loc=7, column='Order_month', value=df['Order Date'].dt.month)
df.insert(loc=8, column='Order_year', value=df['Order Date'].dt.year)

# %%
df.insert(loc=9, column='Ship_day', value=df['Ship Date'].dt.day)
df.insert(loc=10, column='Ship_month', value=df['Ship Date'].dt.month)
df.insert(loc=11, column='Ship_year', value=df['Ship Date'].dt.year)     #seperating date, month, year

# %%
df.head(2)
# Out:
#   Order Date  Ship Date     Ship Mode Customer ID order_month_year  \
# 0 2017-11-08 2017-11-11  Second Class    CG-12520          2017-11
# 1 2017-11-08 2017-11-11  Second Class    CG-12520          2017-11
#
#   ship_month_year  Order_day  Order_month  Order_year  Ship_day  ...  \
# 0         2017-11          8           11        2017        11  ...
# 1         2017-11          8           11        2017        11  ...
#
#     Segment        Country       City     State Postal Code Region   Category  \
# 0  Consumer  United States  Henderson  Kentucky       42420  South  Furniture
# 1  Consumer  United States  Henderson  Kentucky       42420  South  Furniture
#
#   Sub-Category                                       Product Name   Sales
# 0    Bookcases                  Bush Somerset Collection Bookcase  261.96
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
#
# [2 rows x 22 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
df.head(2)
# Out:
#   Order Date  Ship Date     Ship Mode Customer ID order_month_year  \
# 0 2017-11-08 2017-11-11  Second Class    CG-12520          2017-11
# 1 2017-11-08 2017-11-11  Second Class    CG-12520          2017-11
#
#   ship_month_year  Order_day  Order_month  Order_year  Ship_day  Ship_month  \
# 0         2017-11          8           11        2017        11          11
# 1         2017-11          8           11        2017        11          11
#
#    Ship_year   Segment        Country       City     State  Postal Code  \
# 0       2017  Consumer  United States  Henderson  Kentucky        42420
# 1       2017  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category  \
# 0  South  Furniture    Bookcases
# 1  South  Furniture       Chairs
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %%
df.Sales.describe()
# Out:
# count     9799.000000
# mean       230.763895
# std        626.683644
# min          0.444000
# 25%         17.248000
# 50%         54.480000
# 75%        210.572000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
sns.displot(df['Sales'], kde=True, aspect=2, color='slategray', bins=100);

# %% [markdown]
# Observation - Approx Product Sales are 12K to 26K

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df['Sales'])
# Out:
# <Axes: >

# %%
color_list=['slategray','darkslategray','steelblue','teal','cadetblue','powderblue']
df['Ship Mode'].value_counts().plot.bar(color = color_list)
plt.xticks(rotation=360);

# %% [markdown]
# Observation
#
# 5859 orders were shipped by Standrad Class ship mode

# %%
df['Segment'].value_counts().plot.bar(color=color_list)
plt.xticks(rotation=360);

# %% [markdown]
# Observation - Approx 52% of segments for product sales was Consumers

# %%
plt.figure(figsize=(25,4))
df['State'].value_counts().plot.bar(color = color_list)
plt.xticks(rotation=60);

# %% [markdown]
# Observation-Approx 20% order was placed by State California

# %%
plt.figure(figsize=(25,4))
df['City'].value_counts().head(25).plot.bar(color = color_list)
plt.xticks(rotation=40);

# %% [markdown]
# Observation-New York City citizen were contributing approx 9% in overall product sales

# %%
df['Region'].value_counts().plot.pie(subplots=True, autopct = '%1.0f%%', colors=color_list);

# %%
df['Category'].value_counts().plot.pie(subplots=True,autopct='%1.0f%%',colors=color_list);

# %%
plt.figure(figsize=(25,7))
df['Sub-Category'].value_counts().plot.bar(color = color_list)
plt.xticks(rotation=360);

# %% [markdown]
# Observation - In overall sub-category approx 15% are Binders

# %%
plt.figure(figsize=(12,6))
df['Product Name'].value_counts().head(25).sort_values().plot.barh(color = 'Slategrey')
plt.xlabel('Count');

# %%
plt.figure(figsize=(12,7))
df['Product Name'].value_counts().sort_values(ascending=False).tail(25).plot.barh(color = 'Slategrey');

# %% [markdown]
# Observation - Staple envelope, Staples, Easy-staple paper are most ordered product
#
# Xiaomi Mi3, Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream, Socket Bluetooth Cordless Hand Scanner (CHS), Logitech Illuminated Ultrathin Keyboard with Backlighting, LG G2 are less orderd product

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'order_month_year', 'ship_month_year', 'Order_day', 'Order_month',
#        'Order_year', 'Ship_day', 'Ship_month', 'Ship_year', 'Segment',
#        'Country', 'City', 'State', 'Postal Code', 'Region', 'Category',
#        'Sub-Category', 'Product Name', 'Sales'],
#       dtype='object')

# %%
df['Shipping_days'] = df['Ship Date'] - df['Order Date']
time_taken = df['Shipping_days'].value_counts().sort_values().plot.barh(color=color_list)
plt.xlabel('count')
# Out:
# Text(0.5, 0, 'count')

# %% [markdown]
# Observation-The Maximum days taken for the shipping after order was placed is for 4 days

# %%
top_customer = df.groupby('Customer ID').agg({'Sales': sum}).sort_values(by = 'Sales', ascending =  False).head(10).plot.barh(color=color_list)
plt.gca().invert_yaxis()
plt.xlabel('Sales');

# %% [markdown]
# Observation - Here the top 10 Customer who bought the product maybe at high amount or product which have high cost here Customer ID SM-20320 is on top

# %%
top_states = df.groupby('State').agg({'Sales':sum}).sort_values(by='Sales', ascending=False).round(2).head(15).plot.barh(color=color_list)
plt.gca().invert_yaxis()
plt.xlabel('Sales');

# %% [markdown]
# Observation-Above chart shows top 15 States from which California is the on the top in terms of the Sales

# %%
top_cities = df.groupby('City').agg({'Sales':sum}).sort_values(by='Sales',ascending=False).round(2).head(15).plot.barh(color='Slategray')
plt.gca().invert_yaxis()
plt.xlabel('Sales');

# %% [markdown]
# Observation-The above bar chart shows top 15 cities out of 529 cities based on their Sales.
# Most of the sales are done by New York City.

# %%
df.loc[df['State']=='California',['City','Sales']].groupby('City')['Sales'].sum().sort_values(ascending=False).head(15).plot.barh(color='Slategray');
plt.gca().invert_yaxis()
plt.xlabel('Sales');

# %% [markdown]
# Observation-As we saw in above bar chart California State is having most Sales so lets have look which cities are contributed to it.
# Out of 80 cities in California here are top 15 cites from which Los Angeles have most sales.

# %%
df.groupby("Ship Mode").agg({'Sales':sum}).plot.pie(subplots=True, explode = [0,0,0,0.2],autopct='%1.0f%%',colors=['slategray','steelblue','teal','darkslategray']);

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True);
